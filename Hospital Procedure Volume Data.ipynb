# %%
#### Goal: Analyze and integrate the data from the 'Hospital Volume' Datasets.
## Each table has the number of each kind of procedure performed at that hospital.

### 2012
## File:
# Medicare Payment and Volume Measures.csv
## Columns:
# "Provider Number",
# "Diagnosis Related Group",
# "Number Of Cases" -- Missing data is "*".
## Other info:
# This file includes extra columns for "Medicare Average Payment", but it never seems to have data.

### 2013
## File:
# Medicare Volume Measures.csv
## Columns:
# "Provider Number"
# "Diagnosis Related Group",
# "Number Of Cases"  -- Missing data is "*"

### 2014 (will not be used)
## File:
# Medicare Volume - Hospital.csv
## Columns:
# "Provider ID"
# "Diagnosis Related Group",
# "Denominator": (i.e. number of cases). Missing data is denoted by "".

### Summary
# -- All the differenct procedures seem to have the same names (e.g. "Major small and large bowel procedures w MCC") 
#    across all three years.
# -- There are roughly 100 different procedures...I doubt most of them will be helpful.
# -- We could run that one analysis (the "lift" curve?) for each procedures to see which ones help the most.
# -- Alternatively, we could calculate a composite statistic.
#    E.g., the total number of procedures done by the hospital in a given year. 
#   Seems too reductive. many procedures probably don't even use a central line.
# -- This data is nice because we have it for all three years, and it varies in each year.

# %%
#### Tasks to complete

## 1) Read either the 2012 or 2013 tables into a common data frame format, e.g.
# [Provider ID, Composite Volume Statistic], or if you prefer
# [Provider ID, Volume Measure 1, Volume Measure 2, ...]

## 2) Read both data frames into one dataframe that summarizes both years. For example:
# [Provider ID, Composite Volume Statistic 2012, Composite Volume Statistic 2013]
# [Provider ID, Average Composite Volume Statistic]

# %%
import sys
sys.path.append('src')
sys.path.append('data')

import numpy as np
import pandas as pd

# %%
## Task 1) Read either the 2012 or 2013 tables into a common data frame format, e.g.
# [Provider ID, Composite Volume Statistic], or if you prefer
# [Provider ID, Volume Measure 1, Volume Measure 2, ...]

import data_utils
df_2013 = data_utils.parseFile('data/2013/Medicare Volume Measures.csv', 
                               ['Provider Number', 'Diagnosis Related Group', 'Number Of Cases'])
df_2012 = data_utils.parseFile('data/2012/Medicare Payment and Volume Measures.csv', 
                               ['Provider Number', 'Diagnosis Related Group', 'Number Of Cases'])
mincases = '10'
missing_marker = '*'

# %%
## Task 2) Read both data frames into one dataframe that summarizes both years. For example:
# [Provider ID, Composite Volume Statistic 2012, Composite Volume Statistic 2013]
# [Provider ID, Average Composite Volume Statistic]

# TODO
for df in [df_2013, df_2012]:
    df['Number Of Cases'][df['Number Of Cases'] == missing_marker] = mincases
    df['Number Of Cases'] = df['Number Of Cases'].str.replace(",", "")
    df['Number Of Cases'] = df['Number Of Cases'].astype(float)
    
    df.set_index('Provider ID', drop=True, inplace=True)
    dummy_df = pd.DataFrame(index=df.index)
    
    cols = pd.unique(df['Diagnosis Related Group'])
    for col in cols:
        
df_2013
# Out:
#         Provider Number                            Diagnosis Related Group  \
# 0                 10001  Acute myocardial infarction, discharged alive ...
# 1                 10005  Acute myocardial infarction, discharged alive ...
# 2                 10006  Acute myocardial infarction, discharged alive ...
# 3                 10007  Acute myocardial infarction, discharged alive ...
# 4                 10011  Acute myocardial infarction, discharged alive ...
# 5                 10012  Acute myocardial infarction, discharged alive ...
# 6                 10024  Acute myocardial infarction, discharged alive ...
# 7                 10025  Acute myocardial infarction, discharged alive ...
# 8                 10029  Acute myocardial infarction, discharged alive ...
# 9                 10032  Acute myocardial infarction, discharged alive ...
# 10                10033  Acute myocardial infarction, discharged alive ...
# 11                10016  Acute myocardial infarction, discharged alive ...
# 12                10019  Acute myocardial infarction, discharged alive ...
# 13                10021  Acute myocardial infarction, discharged alive ...
# 14                10022  Acute myocardial infarction, discharged alive ...
# 15                10023  Acute myocardial infarction, discharged alive ...
# 16                10040  Acute myocardial infarction, discharged alive ...
# 17                10045  Acute myocardial infarction, discharged alive ...
# 18                10046  Acute myocardial infarction, discharged alive ...
# 19                10047  Acute myocardial infarction, discharged alive ...
# 20                10049  Acute myocardial infarction, discharged alive ...
# 21                10052  Acute myocardial infarction, discharged alive ...
# 22                10054  Acute myocardial infarction, discharged alive ...
# 23                10055  Acute myocardial infarction, discharged alive ...
# 24                10078  Acute myocardial infarction, discharged alive ...
# 25                10079  Acute myocardial infarction, discharged alive ...
# 26                10083  Acute myocardial infarction, discharged alive ...
# 27                10085  Acute myocardial infarction, discharged alive ...
# 28                10086  Acute myocardial infarction, discharged alive ...
# 29                10089  Acute myocardial infarction, discharged alive ...
# ...                 ...                                                ...
# 134641           510055  Uterine and adnexa proc for non-malignancy w/o...
# 134642           510058  Uterine and adnexa proc for non-malignancy w/o...
# 134643           490113  Uterine and adnexa proc for non-malignancy w/o...
# 134644           490114  Uterine and adnexa proc for non-malignancy w/o...
# 134645           490115  Uterine and adnexa proc for non-malignancy w/o...
# 134646           500060  Uterine and adnexa proc for non-malignancy w/o...
# 134647           500064  Uterine and adnexa proc for non-malignancy w/o...
# 134648           500072  Uterine and adnexa proc for non-malignancy w/o...
# 134649           520139  Uterine and adnexa proc for non-malignancy w/o...
# 134650           520160  Uterine and adnexa proc for non-malignancy w/o...
# 134651           510062  Uterine and adnexa proc for non-malignancy w/o...
# 134652           510070  Uterine and adnexa proc for non-malignancy w/o...
# 134653           490118  Uterine and adnexa proc for non-malignancy w/o...
# 134654           500077  Uterine and adnexa proc for non-malignancy w/o...
# 134655           500079  Uterine and adnexa proc for non-malignancy w/o...
# 134656           670023  Uterine and adnexa proc for non-malignancy w/o...
# 134657           670024  Uterine and adnexa proc for non-malignancy w/o...
# 134658           670031  Uterine and adnexa proc for non-malignancy w/o...
# 134659           670041  Uterine and adnexa proc for non-malignancy w/o...
# 134660           670043  Uterine and adnexa proc for non-malignancy w/o...
# 134661           670055  Uterine and adnexa proc for non-malignancy w/o...
# 134662           670060  Uterine and adnexa proc for non-malignancy w/o...
# 134663           670066  Uterine and adnexa proc for non-malignancy w/o...
# 134664           670068  Uterine and adnexa proc for non-malignancy w/o...
# 134665           670069  Uterine and adnexa proc for non-malignancy w/o...
# 134666           670075  Uterine and adnexa proc for non-malignancy w/o...
# 134667           670076  Uterine and adnexa proc for non-malignancy w/o...
# 134668           670077  Uterine and adnexa proc for non-malignancy w/o...
# 134669           670004  Uterine and adnexa proc for non-malignancy w/o...
# 134670           670006  Uterine and adnexa proc for non-malignancy w/o...
#
#         Number Of Cases
# 0                    26
# 1                    10
# 2                    12
# 3                    10
# 4                    10
# 5                    10
# 6                    18
# 7                    10
# 8                    10
# 9                    10
# 10                   18
# 11                   23
# 12                   10
# 13                   10
# 14                   10
# 15                   17
# 16                   23
# 17                   10
# 18                   10
# 19                   10
# 20                   10
# 21                   10
# 22                   10
# 23                   18
# 24                   17
# 25                   10
# 26                   10
# 27                   10
# 28                   10
# 29                   10
# ...                 ...
# 134641               39
# 134642               30
# 134643               12
# 134644               10
# 134645               10
# 134646               10
# 134647               10
# 134648               10
# 134649               26
# 134650               10
# 134651               10
# 134652               14
# 134653               16
# 134654               10
# 134655               10
# 134656               10
# 134657               10
# 134658               10
# 134659               10
# 134660               10
# 134661               10
# 134662               10
# 134663               12
# 134664               10
# 134665               10
# 134666               10
# 134667               10
# 134668               10
# 134669               10
# 134670               10
#
# [134671 rows x 3 columns]
