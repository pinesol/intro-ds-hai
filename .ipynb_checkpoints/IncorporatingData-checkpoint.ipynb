# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sys,os

from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn.metrics import roc_curve, auc

sys.path.append('src/')

# %%
import hai_data_cleanup
reload(hai_data_cleanup)

# Only 2014, 2013, and 2012 are currently avaiable (and I think they always track the previous year, but whatevs).
data_year_files = ['data/2012/Healthcare_Associated_Infections.csv',
                   'data/2013/Healthcare_Associated_Infections.csv', 
                   'data/2014/Healthcare Associated Infections - Hospital.csv']
#data_years = np.arange(2005, 2014)
data_years = np.arange(2012,2014+1).astype('str')

dfs = []

for year, filename in zip(data_years, data_year_files):
    df = hai_data_cleanup.parseHAIFile(filename, year)
    dfs.append(df)

# %%
df_joined = dfs[0]
for year in range(len(data_years)):
    df_joined = df_joined.merge(dfs[year], how='left', on=dfs[year].columns.drop('Score').tolist(), 
                                suffixes=('',' ' + data_years[year]))
df_joined = df_joined.drop('Score',1)
df_joined.head(15)
# Out:
#     Provider ID         City State  ZIP Code County Name Measure ID  \
# 0         30007   COTTONWOOD    AZ     86326     YAVAPAI  HAI_1_SIR
# 1         30010       TUCSON    AZ     85745        PIMA  HAI_1_SIR
# 2         30011       TUCSON    AZ     85711        PIMA  HAI_1_SIR
# 3         30012     PRESCOTT    AZ     86301     YAVAPAI  HAI_1_SIR
# 4         30013         YUMA    AZ     85364        YUMA  HAI_1_SIR
# 5         30014      PHOENIX    AZ     85020    MARICOPA  HAI_1_SIR
# 6         30016  CASA GRANDE    AZ     85222       PINAL  HAI_1_SIR
# 7         30022      PHOENIX    AZ     85008    MARICOPA  HAI_1_SIR
# 8         30023    FLAGSTAFF    AZ     86001    COCONINO  HAI_1_SIR
# 9         30024      PHOENIX    AZ     85013    MARICOPA  HAI_1_SIR
# 10        30030      PHOENIX    AZ     85015    MARICOPA  HAI_1_SIR
# 11        30033       PAYSON    AZ     85541        GILA  HAI_1_SIR
# 12        30036     CHANDLER    AZ     85224    MARICOPA  HAI_1_SIR
# 13        30037      PHOENIX    AZ     85006    MARICOPA  HAI_1_SIR
# 14        30038   SCOTTSDALE    AZ     85251    MARICOPA  HAI_1_SIR
#
#     Score 2012  Score 2013  Score 2014
# 0          NaN       0.000       0.000
# 1         0.49       0.548       0.216
# 2         0.23       0.077       0.230
# 3         1.13       0.000       0.518
# 4         0.00       0.337       0.449
# 5         1.11       1.421       1.101
# 6         0.65       0.000       0.384
# 7         1.65       0.993       1.365
# 8         0.29       0.289       0.588
# 9         0.74       0.687       0.458
# 10        0.79       0.158       0.442
# 11         NaN         NaN         NaN
# 12        0.79       0.184       0.000
# 13        1.25       0.589       0.521
# 14        0.08       0.451       0.649

# %%
len(dfs[0])
hospitals3 = pd.unique(dfs[0]['Provider ID'])

# %%
hospitals2.sort()
hospitals3.sort()
for x in hospitals2:
    if x not in hospitals3:
        print x
# Out:
# 10091
# 11304
# 13301
# 20018
# 21301
# 21302
# 21303
# 21304
# 21305
# 21307
# 21308
# 21309
# 21312
# 21313
# 30074
# 400120
# 400121
# 400125
# 400126
# 400130
# 420105
# 421300
# 421303
# 430081
# 430082
# 430083
# 430084
# 430097
# 431300
# 431306
# 431307
# 431308
# 431309
# 431310
# 431311
# 431312
# 431315
# 431316
# 431317
# 431320
# 431321
# 431322
# 431323
# 431324
# 431325
# 431326
# 431327
# 431329
# 431330
# 431331
# 431332
# 431333
# 431335
# 431336
# 431337
# 440007
# 440010
# 440040
# 440141
# 440147
# 440181
# 440182
# 440218
# 440231
# 440232
# 441300
# 441301
# 441305
# 441307
# 441308
# 441309
# 441310
# 441311
# 441313
# 441314
# 441316
# 450052
# 450078
# 450241
# 450243
# 450253
# 450270
# 450293
# 450306
# 450348
# 450373
# 450399
# 450446
# 450451
# 450460
# 450488
# 450497
# 450498
# 450578
# 450586
# 450620
# 450641
# 450654
# 450698
# 450746
# 450749
# 450770
# 450797
# 450884
# 451301
# 451302
# 451303
# 451305
# 451309
# 451310
# 451311
# 451313
# 451315
# 451316
# 451320
# 451321
# 451322
# 451326
# 451330
# 451331
# 451333
# 451334
# 451337
# 451341
# 451342
# 451343
# 451344
# 451347
# 451349
# 451351
# 451353
# 451354
# 451357
# 451361
# 451363
# 451364
# 451366
# 451372
# 451373
# 451379
# 451380
# 453300
# 453301
# 453310
# 460059
# 460060
# 461302
# 461305
# 461306
# 461308
# 461309
# 461310
# 463301
# 471300
# 471302
# 471304
# 471305
# 471307
# 480002
# 490105
# 490106
# 490109
# 490134
# 490143
# 491300
# 491302
# 491303
# 491304
# 491306
# 491307
# 501301
# 501302
# 501303
# 501304
# 501305
# 501307
# 501308
# 501309
# 501310
# 501311
# 501312
# 501313
# 501315
# 501316
# 501317
# 501318
# 501319
# 501320
# 501321
# 501322
# 501327
# 501330
# 501334
# 501337
# 501338
# 501340
# 503300
# 511301
# 511303
# 511304
# 511307
# 511309
# 511311
# 511313
# 511320
# 520195
# 520208
# 521302
# 521303
# 521304
# 521305
# 521308
# 521309
# 521310
# 521314
# 521316
# 521319
# 521320
# 521321
# 521323
# 521325
# 521329
# 521331
# 521332
# 521333
# 521336
# 521337
# 521338
# 521339
# 521345
# 521347
# 521353
# 521356
# 521358
# 521359
# 531316
# 650001
# 660001
# 670010
# 670021
# 670045
# 670050
# 670058
# 670061
# 670062
# 670078
# 670079
# 670080
# 670082
# 670083
# 670085
# 670087
# 670088
# 670089

# %%
for col in df_joined.columns[6:]:
    print 'NA: ' + str(sum(pd.isnull(df_joined[col])))
    print 'below 1 : ' + str(sum(df_joined[col] <= 1.00))
    print 'above 1 : ' + str(sum(df_joined[col] > 1.00))
# Out:
# NA: 1630
# below 1 : 1987
# above 1 : 0
# NA: 1665
# below 1 : 1952
# above 1 : 0
# NA: 1655
# below 1 : 1962
# above 1 : 0

# %%
def binByScore1(df, col):
    #cols = df.columns[pd.Series(df.columns).str.contains('Score')]
    def binning(score):
        if np.isnan(score):
            return np.nan
        elif score > 1:
            return -1
        else: 
            return 1
    df2 = df.drop(col, 1)
    df2[col] = df[col].map(binning)
    return df2

def binByScore2(df, col, lower = -2, upper = 2):
    #cols = df.columns[pd.Series(df.columns).str.contains('Score')]
    def binning(z):
            if np.isnan(z):
                return np.nan
            elif z > upper:
                return -1
            elif z < lower:
                return 1
            else: 
                return 0
    mean = np.mean(df[col])
    sd = np.std(df[col])
    z_scores = df[col].map(lambda score: (score - mean)/sd)
    df2 = df.drop(col, 1)
    df2[col] = z_scores.map(binning)
    return df2

# %%
def binByScore3(df, col, quantile = .20):
    df = df.sort(col, ascending=False)
    ncases = sum(df[col].notnull())
    nmissing = sum(df[col].isnull())
    df2 = df
    df2[col][:quantile*ncases] = -1
    df2[col][quantile*ncases:-(nmissing+quantile*ncases)] = 0
    df2[col][-(nmissing+quantile*ncases):-nmissing] = 1
    return df2

# %%
for col in df_joined.columns[6:]:
    df2 = binByScore2(df_joined, col)
    print 'NA: ' + str(sum(pd.isnull(df2[col])))
    print 'better: ' + str(sum(df2[col] == 1.00))
    print 'no different: ' +str(sum(df2[col] == 0))
    print 'worse: ' + str(sum(df2[col] == -1.00))
# Out:
# NA: 1630
# better: 0
# no different: 1894
# worse: 93
# NA: 1665
# better: 0
# no different: 1874
# worse: 78
# NA: 1655
# better: 421
# no different: 1448
# worse: 93

# %%
df_joined['Score 2012'] > 1 & df_joined['Score 2012'].notnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 3602    False
# 3603    False
# 3604    False
# 3605    False
# 3606    False
# 3607    False
# 3608    False
# 3609    False
# 3610    False
# 3611    False
# 3612    False
# 3613    False
# 3614    False
# 3615    False
# 3616    False
# Name: Score 2012, Length: 3617, dtype: bool

# %%
reload(hai_data_cleanup)
dfs_binned = []
for year, filename in zip(data_years, data_year_files):
    df_binned = hai_data_cleanup.parseHAIbyBinLabel(filename, year)
    df2 = hai_data_cleanup.parseHAIFile(filename, year)
    df_binned
    dfs_binned.append(df_binned)

# %%
reload(hai_data_cleanup)
d2014 = hai_data_cleanup.parseHAIbyBinLabel('data/2014/Healthcare Associated Infections - Hospital.csv', '2014')
d2013 = hai_data_cleanup.parseHAIbyBinLabel('data/2013/Healthcare_Associated_Infections.csv', '2013')
d2012 = hai_data_cleanup.parseHAIbyBinLabel('data/2012/Healthcare_Associated_Infections.csv', '2012')

# %%
len(d2014)
hospitals = pd.unique(d2014['Provider ID'])
hospitals2 = pd.unique(df_binned['Provider ID'])

# %%
reload(hai_data_cleanup)
d2014 = hai_data_cleanup.parseHAIbyBinLabel('data/2014/Healthcare Associated Infections - Hospital.csv', '2014')
d2 = hai_data_cleanup.parseHAIFile('data/2014/Healthcare Associated Infections - Hospital.csv', '2014')

# %%
reload(hai_data_cleanup)
#hai_data_cleanup.parseHAIboth('data/2014/Healthcare Associated Infections - Hospital.csv', '2014')
d2014
# Out:
#                         City State  Compared to National
# Provider ID
# 10001                 DOTHAN    AL                     0
# 10005                   BOAZ    AL                     0
# 10006               FLORENCE    AL                     0
# 10007                    OPP    AL                   NaN
# 10008                LUVERNE    AL                   NaN
# 10011             BIRMINGHAM    AL                     0
# 10012             FORT PAYNE    AL                   NaN
# 10016              ALABASTER    AL                     1
# 10018             BIRMINGHAM    AL                   NaN
# 10019              SHEFFIELD    AL                     0
# 10021                  OZARK    AL                   NaN
# 10022                 CENTRE    AL                   NaN
# 10023             MONTGOMERY    AL                     1
# 10024             MONTGOMERY    AL                     0
# 10025                 VALLEY    AL                   NaN
# 10029                OPELIKA    AL                     0
# 10032                WEDOWEE    AL                   NaN
# 10033             BIRMINGHAM    AL                     0
# 10034              TALLASSEE    AL                   NaN
# 10035                CULLMAN    AL                     0
# 10036              ANDALUSIA    AL                   NaN
# 10038               ANNISTON    AL                   NaN
# 10039             HUNTSVILLE    AL                     0
# 10040                GADSDEN    AL                     1
# 10044               HAMILTON    AL                   NaN
# 10045                FAYETTE    AL                   NaN
# 10046                GADSDEN    AL                    -1
# 10047              GEORGIANA    AL                   NaN
# 10049             ENTERPRISE    AL                   NaN
# 10051                  EUTAW    AL                   NaN
# ...                      ...   ...                   ...
# 670049                DALLAS    TX                   NaN
# 670050               LUBBOCK    TX                   NaN
# 670053            SUGAR LAND    TX                     0
# 670054           SAN ANTONIO    TX                   NaN
# 670055           SAN ANTONIO    TX                     0
# 670056                  KYLE    TX                     1
# 670058            SUGAR LAND    TX                   NaN
# 670059         THE WOODLANDS    TX                   NaN
# 670060             SUNNYVALE    TX                     0
# 670061        CORPUS CHRISTI    TX                   NaN
# 670062                AUBREY    TX                   NaN
# 670066                ODESSA    TX                   NaN
# 670067             ARLINGTON    TX                   NaN
# 670068          FLOWER MOUND    TX                     0
# 660001               GARAPAN    MP                   NaN
# 670069             MC KINNEY    TX                   NaN
# 670071             ARLINGTON    TX                     0
# 670073               ADDISON    TX                   NaN
# 670075               HOUSTON    TX                     0
# 670076               SHERMAN    TX                   NaN
# 670077               HOUSTON    TX                     0
# 670078           SAN ANTONIO    TX                   NaN
# 670079               LAKEWAY    TX                     0
# 670080        HARKER HEIGHTS    TX                   NaN
# 670082             MC KINNEY    TX                     0
# 670083         GRAND PRAIRIE    TX                   NaN
# 670085            FORT WORTH    TX                   NaN
# 670087            CEDAR PARK    TX                   NaN
# 670088       COLLEGE STATION    TX                   NaN
# 670089                DILLEY    TX                   NaN
#
# [4683 rows x 3 columns]

# %%
values = [-1, 0, 1]
for year in [d2014, d2013, d2012]:
    for v in values:
        x = np.sum(year['Compared to National'] == v)
        print str(v) + ': ' + str(x)
    x = np.sum(pd.isnull(year['Compared to National']))
    print 'Nan: ' + str(x)
# Out:
# -1: 23
# 0: 1401
# 1: 581
# Nan: 2678
# -1: 35
# 0: 1445
# 1: 491
# Nan: 2696
# -1: 39
# 0: 1110
# 1: 489
# Nan: 1979

# %%
df_joinedBins = dfs_binned[0]
for year in range(len(data_years)):
    df_joinedBins = df_joinedBins.merge(dfs_binned[year], how='left', 
                                on=dfs_binned[year].columns.drop('Compared to National').tolist(), 
                                suffixes=('',' ' + data_years[year]))
df_joinedBins = df_joinedBins.drop('Compared to National',1)
df_joinedBins.head(15)
# Out:
#     Provider ID             City State  ZIP Code County Name     Measure ID  \
# 0        390114       PITTSBURGH    PA     15213   ALLEGHENY  HAI_1_compare
# 1        321302        TUCUMCARI    NM     88401        QUAY  HAI_1_compare
# 2        420002        ROCK HILL    SC     29730        YORK  HAI_1_compare
# 3        450697      SAN ANTONIO    TX     78224       BEXAR  HAI_1_compare
# 4        510007       HUNTINGTON    WV     25701      CABELL  HAI_1_compare
# 5        260061           NEVADA    MO     64772      VERNON  HAI_1_compare
# 6        450395       LIVINGSTON    TX     77351        POLK  HAI_1_compare
# 7        110125           DUBLIN    GA     31021     LAURENS  HAI_1_compare
# 8        420037     SIMPSONVILLE    SC     29681  GREENVILLE  HAI_1_compare
# 9        380038      OREGON CITY    OR     97045   CLACKAMAS  HAI_1_compare
# 10       521315           BARRON    WI     54812      BARRON  HAI_1_compare
# 11       310075      LONG BRANCH    NJ      7740    MONMOUTH  HAI_1_compare
# 12        10149       MONTGOMERY    AL     36117  MONTGOMERY  HAI_1_compare
# 13       180011           LONDON    KY     40741      LAUREL  HAI_1_compare
# 14       100287  WEST PALM BEACH    FL     33401  PALM BEACH  HAI_1_compare
#
#     Compared to National 2012  Compared to National 2013  \
# 0                           1                          0
# 1                         NaN                        NaN
# 2                           0                          0
# 3                           0                          0
# 4                           0                          1
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                           0                          0
# 8                         NaN                        NaN
# 9                         NaN                        NaN
# 10                        NaN                        NaN
# 11                          0                          0
# 12                          0                          0
# 13                          0                          0
# 14                          0                          0
#
#     Compared to National 2014
# 0                           0
# 1                         NaN
# 2                           0
# 3                           0
# 4                           1
# 5                         NaN
# 6                         NaN
# 7                           0
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                          0
# 12                          0
# 13                          0
# 14                          0

# %%
dfs_binned[2]['Compared to National'].value_counts()
# Out:
#  0    1401
#  1     581
# -1      23
# dtype: int64

# %%
values = [-1, 0, 1]
for year in ['2014', '2013', '2012']:
    for v in values:
        x = np.sum(df_joinedBins['Compared to National ' + year] == v)
        print str(v) + ': ' + str(x)
    x = np.sum(pd.isnull(df_joinedBins['Compared to National ' + year]))
    print 'Nan: ' + str(x)
# Out:
# -1: 23
# 0: 1368
# 1: 571
# Nan: 1655
# -1: 35
# 0: 1430
# 1: 487
# Nan: 1665
# -1: 39
# 0: 1110
# 1: 489
# Nan: 1979

# %%
import data_utils
filename = 'data/2012/Healthcare_Associated_Infections.csv'
year_str = '2012'

data = data_utils.parseFile(filename, ['Provider ID', 'City', 'State', 'ZIP Code', 'County Name', 'Measure', 'Score'])
data = hai_data_cleanup.binByCI(data, 'CLABSI Lower Confidence Limit', 'CLABSI Upper Confidence Limit', 'Score')
data.to_csv('2012_compare.csv')
